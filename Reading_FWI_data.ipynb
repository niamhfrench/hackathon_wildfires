# %%
import numpy as np
fwi_data = np.load('UK_FWI.npy')

# %%
import matplotlib.pyplot as plt
plt.plot(fwi_data[4,:,3,3])

# %%
msr_data = np.load('UK_MSR.npy')

# %%
print(msr_data.shape)
# Out:
# (1200, 112, 82)

# %%
plt.plot(msr_data[:,30,39]) # [time,lat,lon]

# %%
msr_lon_avg = np.average(msr_data,axis = 2)
plt.plot(msr_lon_avg[:,110]) # [time,lat,lon]

# %%
for i in range(1200):
    im[i] = plt.imshow(msr_data[i,:,:])
